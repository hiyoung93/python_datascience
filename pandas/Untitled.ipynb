# %%
import pandas as pd

# %%
s = pd.Series([9904312, 3448737, 2890451, 2466052],
              index=["서울", "부산", "인천", "대구"])
s
# Out:
# 서울    9904312
# 부산    3448737
# 인천    2890451
# 대구    2466052
# dtype: int64

# %%
pd.Series(range(10,14)) # 대문자 사용하기
# Out:
# 0    10
# 1    11
# 2    12
# 3    13
# dtype: int64

# %%
s.index
# Out:
# Index(['서울', '부산', '인천', '대구'], dtype='object')

# %%
s.values
# Out:
# array([9904312, 3448737, 2890451, 2466052], dtype=int64)

# %%
시리즈 연산 - 벡터화 연산가능,
시리즈 값에만 적용, index 값은 변하지 않음
